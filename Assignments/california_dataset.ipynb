# %%
import numpy as np
import pandas as pd
import pandas_profiling 
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
data=pd.read_csv('https://raw.githubusercontent.com/KarinkiManikanta/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/california_cities.csv')

# %%
data
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
pandas_profiling.ProfileReport(data)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr())

# %%
data.head()
# Out:
#    Unnamed_0         city       latd       longd  elevation_m  elevation_ft  \
# 0          0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1          1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2          2      Alameda  37.756111 -122.274444          NaN          33.0
# 3          3       Albany  37.886944 -122.297778          NaN          43.0
# 4          4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# ...

# %%
data.tail()
# Out:
#      Unnamed_0         city       latd       longd  elevation_m  elevation_ft  \
# 477        477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479        479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480        480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481        481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 477              2933             1.531            1.531             0.000
# 478              7765            10.053            9.980             0.073
# 479             64925            14.656           14.578             0.078
# 480             51367            27.893           27.888             0.005
# 481             20700            40.015           40.015             0.000
#
# ...

# %%
data.shape
# Out:
# (482, 14)

# %%
data.ndim
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed_0           482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         434 non-null    float64
#  5   elevation_ft        470 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    480 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    481 non-null    float64
#  10  area_total_km2      477 non-null    float64
#  11  area_land_km2       478 non-null    float64
#  12  area_water_km2      478 non-null    float64
#  13  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB

# %%
data.describe()
# Out:
#         Unnamed_0        latd       longd  elevation_m  elevation_ft  \
# count  482.000000  482.000000  482.000000   434.000000    470.000000
# mean   240.500000   36.095088 -119.837714   180.416705    567.168723
# std    139.285678    2.298006    2.147676   309.531825   1001.265722
# min      0.000000   32.578333 -124.263333   -34.000000   -180.000000
# 25%    120.250000   33.977292 -121.954931    22.000000     69.000000
# 50%    240.500000   36.204722 -119.708611    67.000000    200.000000
# 75%    360.750000   37.886667 -117.977292   173.500000    515.000000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.820000e+02        480.000000       482.000000        481.000000
# mean       6.489493e+04         18.442183        16.840981          1.589630
# std        2.032041e+05         36.363230        32.694647          9.490386
# ...

# %%
data.isna().sum()
# Out:
# Unnamed_0              0
# city                   0
# latd                   0
# longd                  0
# elevation_m           48
# elevation_ft          12
# population_total       0
# area_total_sq_mi       2
# area_land_sq_mi        0
# area_water_sq_mi       1
# area_total_km2         5
# area_land_km2          4
# area_water_km2         4
# area_water_percent     5
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed_0', 'city', 'latd', 'longd', 'elevation_m', 'elevation_ft',
#        'population_total', 'area_total_sq_mi', 'area_land_sq_mi',
#        'area_water_sq_mi', 'area_total_km2', 'area_land_km2', 'area_water_km2',
#        'area_water_percent'],
#       dtype='object')

# %%
data.drop('Unnamed_0',axis=1)
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 1    AgouraHills  34.153333 -118.761667        281.0         922.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %%
fill=data['elevation_m'].mean()

# %%
fill
# Out:
# 180.41670506912445

# %%
data['elevation_m'].median()
# Out:
# 67.0

# %%
data['elevation_m']=data['elevation_m'].fillna(fill)

# %%
data.isna().sum() # no null valuse in elevation_m
# Out:
# Unnamed_0              0
# city                   0
# latd                   0
# longd                  0
# elevation_m            0
# elevation_ft          12
# population_total       0
# area_total_sq_mi       2
# area_land_sq_mi        0
# area_water_sq_mi       1
# area_total_km2         5
# area_land_km2          4
# area_water_km2         4
# area_water_percent     5
# dtype: int64

# %%
data['elevation_ft'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 477    False
# 478    False
# 479    False
# 480    False
# 481    False
# Name: elevation_ft, Length: 482, dtype: bool

# %%
data['elevation_ft'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 477    True
# 478    True
# 479    True
# 480    True
# 481    True
# Name: elevation_ft, Length: 482, dtype: bool

# %%
data.fillna(method='bfill')
# Out:
#      Unnamed_0         city       latd       longd  elevation_m  elevation_ft  \
# 0            0     Adelanto  34.576111 -117.432778   875.000000        2871.0
# 1            1  AgouraHills  34.153333 -118.761667   281.000000         922.0
# 2            2      Alameda  37.756111 -122.274444   180.416705          33.0
# 3            3       Albany  37.886944 -122.297778   180.416705          43.0
# 4            4     Alhambra  34.081944 -118.135000   150.000000         492.0
# ..         ...          ...        ...         ...          ...           ...
# 477        477   Yountville  38.403056 -122.362222    30.000000          98.0
# 478        478        Yreka  41.726667 -122.637500   787.000000        2582.0
# 479        479     YubaCity  39.134722 -121.626111    18.000000          59.0
# 480        480      Yucaipa  34.030278 -117.048611   798.000000        2618.0
# 481        481  YuccaValley  34.133333 -116.416667  1027.000000        3369.0
#
# ...

# %%
data.isna().sum()
# Out:
# Unnamed_0              0
# city                   0
# latd                   0
# longd                  0
# elevation_m            0
# elevation_ft          12
# population_total       0
# area_total_sq_mi       2
# area_land_sq_mi        0
# area_water_sq_mi       1
# area_total_km2         5
# area_land_km2          4
# area_water_km2         4
# area_water_percent     5
# dtype: int64

# %%
x=data['elevation_ft'].mean()

# %%
x
# Out:
# 567.1687234042553

# %%
data['elevation_ft']=data['elevation_ft'].fillna(x)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      2
# area_land_sq_mi       0
# area_water_sq_mi      1
# area_total_km2        5
# area_land_km2         4
# area_water_km2        4
# area_water_percent    5
# dtype: int64

# %%
data['area_water_percent'].fillna(method='ffill')
# Out:
# 0       0.03
# 1       0.37
# 2      53.79
# 3      67.28
# 4       0.01
#        ...
# 477     0.00
# 478     0.72
# 479     0.53
# 480     0.02
# 481     0.00
# Name: area_water_percent, Length: 482, dtype: float64

# %%
y=data['area_water_percent'].mean()

# %%
y
# Out:
# 5.301800838574423

# %%
data['area_water_percent']=data['area_water_percent'].fillna(y)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      2
# area_land_sq_mi       0
# area_water_sq_mi      1
# area_total_km2        5
# area_land_km2         4
# area_water_km2        4
# area_water_percent    0
# dtype: int64

# %%
z=data['area_water_km2'].mean()

# %%
z
# Out:
# 3.1251782426778236

# %%
data['area_water_km2']=data['area_water_km2'].fillna(z)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      2
# area_land_sq_mi       0
# area_water_sq_mi      1
# area_total_km2        5
# area_land_km2         4
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
a=data['area_total_sq_mi'].mean()

# %%
a
# Out:
# 18.442183333333332

# %%
data['area_total_sq_mi']=data['area_total_sq_mi'].fillna(a)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      1
# area_total_km2        5
# area_land_km2         4
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
b=data['area_total_km2'].mean()

# %%
b
# Out:
# 46.753283018867926

# %%
data['area_total_km2']=data['area_total_km2'].fillna(b)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      1
# area_total_km2        0
# area_land_km2         4
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
c=data['area_water_sq_mi'].mean()

# %%
c
# Out:
# 1.5896299376299377

# %%
data['area_water_sq_mi']=data['area_water_sq_mi'].fillna(c)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         4
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
d=data['area_land_km2'].mean()

# %%
d
# Out:
# 43.54702092050209

# %%
data['area_land_km2']=data['area_land_km2'].fillna(d)

# %%
data.isna().sum()
# Out:
# Unnamed_0             0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
# finally there is no null vallues in the given dataset i filled with mean value
